# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import grangercausalitytests
from nodiensenv.constants import DATA_DIR, FIGURE_DIR
from nodiensenv.analyser import TrendPriceAnalyser

years = [2021, 2022, 2023, 2024]

for year in years:
    trend = "dogecoin"
    coin_name = "DOGE"
    trend_h1 = pd.read_csv(
        DATA_DIR / f"trend_{coin_name}_{year}_H1.csv", parse_dates=["date"]
    )
    trend_h2 = pd.read_csv(
        DATA_DIR / f"trend_{coin_name}_{year}_H2.csv", parse_dates=["date"]
    )
    price = pd.read_csv(DATA_DIR / f"{coin_name}_price_mcap.csv", parse_dates=["date"])

# %%
trend_h1.head()
# Out:
#         date  dogecoin
# 0 2024-01-01        13
# 1 2024-01-02        16
# 2 2024-01-03        15
# 3 2024-01-04        14
# 4 2024-01-05        12

# %%
price.head()
# Out:
#         date      open      high       low     close    volumefrom  \
# 0 2021-01-01  0.004619  0.005741  0.004606  0.005699  3.179644e+08
# 1 2021-01-02  0.005699  0.014080  0.005597  0.010580  3.708311e+09
# 2 2021-01-03  0.010580  0.013860  0.009254  0.009826  2.050835e+09
# 3 2021-01-04  0.009826  0.011510  0.007388  0.009776  1.490013e+09
# 4 2021-01-05  0.009776  0.010300  0.008825  0.009994  3.949869e+08
#
#       volumeto        supply    market_cap
# 0   1639311.25  1.277622e+11  7.281167e+08
# 1  34174268.90  1.277761e+11  1.351872e+09
# 2  23319659.14  1.277902e+11  1.255667e+09
# 3  14197090.74  1.278040e+11  1.249412e+09
# 4   3784489.68  1.278178e+11  1.277411e+09

# %%
price_year = price[price["date"].dt.year == year].sort_values("date")
price_h1 = price_year[(price_year["date"] <= f"{year}-06-30")].copy()
price_h2 = price_year[(price_year["date"] >= f"{year}-07-01")].copy()

for df in (price_h1, price_h2):
    df["log_return"] = np.log(df["close"] / df["close"].shift(1)) * 100
    df["abs_log_return"] = abs(df["log_return"])

for df in (trend_h1, trend_h2):
    df["trend_log_return"] = np.log(df[f"{trend}"] / df[f"{trend}"].shift(1)) * 100
    df["abs_trend_log_return"] = abs(df["trend_log_return"])

# %%
price_h1.head()
# Out:
#            date     open     high      low    close    volumefrom  \
# 1095 2024-01-01  0.08950  0.09208  0.08850  0.09200  1.583649e+08
# 1096 2024-01-02  0.09200  0.09441  0.09042  0.09110  3.562606e+08
# 1097 2024-01-03  0.09110  0.09213  0.07702  0.08203  7.131253e+08
# 1098 2024-01-04  0.08203  0.08475  0.08112  0.08408  3.364691e+08
# 1099 2024-01-05  0.08408  0.08490  0.08041  0.08272  4.966445e+08
#
#          volumeto        supply    market_cap  log_return  abs_log_return
# 1095  14363090.41  1.424803e+11  1.310819e+10         NaN             NaN
# 1096  33026702.48  1.424936e+11  1.298117e+10   -0.983077        0.983077
# 1097  59961786.12  1.425072e+11  1.168987e+10  -10.487277       10.487277
# 1098  27993882.62  1.425342e+11  1.198427e+10    2.468369        2.468369
# 1099  40946885.60  1.425342e+11  1.179043e+10   -1.630732        1.630732

# %%
trend_h1.head()
# Out:
#         date  dogecoin  trend_log_return  abs_trend_log_return
# 0 2024-01-01        13               NaN                   NaN
# 1 2024-01-02        16         20.763936             20.763936
# 2 2024-01-03        15         -6.453852              6.453852
# 3 2024-01-04        14         -6.899287              6.899287
# 4 2024-01-05        12        -15.415068             15.415068

# %%
df_h1 = pd.merge(
    trend_h1,
    price_h1[["date", "close", "log_return", "abs_log_return"]],
    on="date",
    how="inner",
)
df_h2 = pd.merge(
    trend_h2,
    price_h2[["date", "close", "log_return", "abs_log_return"]],
    on="date",
    how="inner",
)

# %%
df_h1.head()
# Out:
#         date  dogecoin  trend_log_return  abs_trend_log_return    close  \
# 0 2024-01-01        13               NaN                   NaN  0.09200
# 1 2024-01-02        16         20.763936             20.763936  0.09110
# 2 2024-01-03        15         -6.453852              6.453852  0.08203
# 3 2024-01-04        14         -6.899287              6.899287  0.08408
# 4 2024-01-05        12        -15.415068             15.415068  0.08272
#
#    log_return  abs_log_return
# 0         NaN             NaN
# 1   -0.983077        0.983077
# 2  -10.487277       10.487277
# 3    2.468369        2.468369
# 4   -1.630732        1.630732

# %%
series_price_h1 = df_h1[["log_return"]].dropna()
series_trend_h1 = df_h1[["trend_log_return"]].dropna()

# %%
series_price_h1
# Out:
#      log_return
# 1     -0.983077
# 2    -10.487277
# 3      2.468369
# 4     -1.630732
# 5     -2.559062
# ..          ...
# 177   -2.733289
# 178    3.365702
# 179   -3.284236
# 180   -0.899802
# 181    2.113900
#
# [181 rows x 1 columns]

# %%
series_price_h1 = df_h1[["log_return"]].dropna()
series_trend_h1 = df_h1[["trend_log_return"]].dropna()
df_gc = pd.concat([series_price_h1, series_trend_h1], axis=1).dropna()
df_gc.columns = ["price_ret", "trend_ret"]

"""
Runs Granger tests up to `max_lag` for both directions:
1) Does trend --> price?
2) Does price --> trend?
Prints a summary for each.
"""

def run_granger(df, max_lag):
    print(f"\n=== Testing Granger causality up to lag={max_lag} ===\n")

    # 3a) trend --> price
    print(">> Does TREND Granger-cause PRICE?")
    test_result_1 = grangercausalitytests(df[["price_ret","trend_ret"]], 
                                        maxlag=max_lag, verbose=True)
    # 3b) price --> trend
    print("\n>> Does PRICE Granger-cause TREND?")
    test_result_2 = grangercausalitytests(df[["trend_ret","price_ret"]], 
                                        maxlag=max_lag, verbose=True)

    return test_result_1, test_result_2

res_trend_to_price, res_price_to_trend = run_granger(df_gc, max_lag=3)
# Out:
# === Testing Granger causality up to lag=3 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0676  , p=0.7952  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=0.0687  , p=0.7932  , df=1
# likelihood ratio test: chi2=0.0687  , p=0.7932  , df=1
# parameter F test:         F=0.0676  , p=0.7952  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3201  , p=0.7265  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=0.6586  , p=0.7194  , df=2
# likelihood ratio test: chi2=0.6574  , p=0.7198  , df=2
# parameter F test:         F=0.3201  , p=0.7265  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6487  , p=0.1800  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=5.1486  , p=0.1612  , df=3
# likelihood ratio test: chi2=5.0756  , p=0.1663  , df=3
# parameter F test:         F=1.6487  , p=0.1800  , df_denom=171, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=10.3370 , p=0.0015  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=10.5122 , p=0.0012  , df=1
# likelihood ratio test: chi2=10.2167 , p=0.0014  , df=1
# parameter F test:         F=10.3370 , p=0.0015  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.2333  , p=0.0062  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=10.7674 , p=0.0046  , df=2
# likelihood ratio test: chi2=10.4560 , p=0.0054  , df=2
# parameter F test:         F=5.2333  , p=0.0062  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.1735  , p=0.0070  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=13.0330 , p=0.0046  , df=3
# likelihood ratio test: chi2=12.5779 , p=0.0056  , df=3
# parameter F test:         F=4.1735  , p=0.0070  , df_denom=171, df_num=3
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(

# %%
year
# Out:
# 2024

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import grangercausalitytests
from nodiensenv.constants import DATA_DIR, FIGURE_DIR
from nodiensenv.analyser import TrendPriceAnalyser

years = [2021, 2022, 2023, 2024]

for year in years:
    trend = "bitcoin"
    coin_name = "BTC"
    trend_h1 = pd.read_csv(
        DATA_DIR / f"trend_{coin_name}_{year}_H1.csv", parse_dates=["date"]
    )
    trend_h2 = pd.read_csv(
        DATA_DIR / f"trend_{coin_name}_{year}_H2.csv", parse_dates=["date"]
    )
    price = pd.read_csv(DATA_DIR / f"{coin_name}_price_mcap.csv", parse_dates=["date"])

    # Filter price to {year}, split H1 & H2, and compute daily log-returns
    price_year = price[price["date"].dt.year == year].sort_values("date")
    price_h1 = price_year[(price_year["date"] <= f"{year}-06-30")].copy()
    price_h2 = price_year[(price_year["date"] >= f"{year}-07-01")].copy()

    for df in (price_h1, price_h2):
        df["log_return"] = np.log(df["close"] / df["close"].shift(1)) * 100
        df["abs_log_return"] = abs(df["log_return"])

    for df in (trend_h1, trend_h2):
        df["trend_log_return"] = np.log(df[f"{trend}"] / df[f"{trend}"].shift(1)) * 100
        df["abs_trend_log_return"] = abs(df["trend_log_return"])

    # Merge each half’s trends with its prices
    df_h1 = pd.merge(
        trend_h1,
        price_h1[["date", "close", "log_return", "abs_log_return"]],
        on="date",
        how="inner",
    )
    df_h2 = pd.merge(
        trend_h2,
        price_h2[["date", "close", "log_return", "abs_log_return"]],
        on="date",
        how="inner",
    )

    series_price_h1 = df_h1[["log_return"]].dropna()
    series_trend_h1 = df_h1[["trend_log_return"]].dropna()
    df_gc = pd.concat([series_price_h1, series_trend_h1], axis=1).dropna()
    df_gc.columns = ["price_ret", "trend_ret"]

    def run_granger(df, max_lag):
        print(f"\n=== Testing Granger causality up to lag={max_lag} in {year} ===\n")

        # 3a) trend --> price
        print(">> Does TREND Granger-cause PRICE?")
        test_result_1 = grangercausalitytests(
            df[["price_ret", "trend_ret"]], maxlag=max_lag, verbose=True
        )
        # 3b) price --> trend
        print("\n>> Does PRICE Granger-cause TREND?")
        test_result_2 = grangercausalitytests(
            df[["trend_ret", "price_ret"]], maxlag=max_lag, verbose=True
        )

        return test_result_1, test_result_2

    res_trend_to_price, res_price_to_trend = run_granger(df_gc, max_lag=3)

    # analyser = TrendPriceAnalyser(trend, df_h1, df_h2)

    # for smooth_window in [3]:
    #         analyser.plot_smoothed(
    #             "H1",
    #             "close",
    #             f"{trend}",
    #             smooth_window,
    #             "Close Price",
    #             f"Google Trend ({trend})",
    #             f"H1 {year}: {coin_name} Close vs Trend (rolling window={smooth_window})",
    #         )
    #         analyser.plot_smoothed(
    #             "H2",
    #             "close",
    #             f"{trend}",
    #             smooth_window,
    #             "Close Price",
    #             f"Google Trend ({trend})",
    #             f"H2 {year}: {coin_name} Close vs Trend (rolling window={smooth_window})",
    #         )
    #     analyser.plot_smoothed(
    #         "H1",
    #         "log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H1 {year}: {coin_name} Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H2",
    #         "log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H2 {year}: {coin_name} Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H1",
    #         "abs_log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H1 {year}: {coin_name} abs Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H2",
    #         "abs_log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H2 {year}: {coin_name} abs Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H1",
    #         "log_return",
    #         "trend_log_return",
    #         smooth_window,
    #         "Price Log Return",
    #         "Trend Log Return",
    #         f"H1 {year}: {coin_name} Price Log Return vs Trend Log Return (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H2",
    #         "log_return",
    #         "trend_log_return",
    #         smooth_window,
    #         "Price Log Return",
    #         "Trend Log Return",
    #         f"H2 {year}: {coin_name} Price Log Return vs Trend Log Return (rolling window={smooth_window})",
    #     )
    # analyser.plot_smoothed(
    #     "H1",
    #     "abs_log_return",
    #     "abs_trend_log_return",
    #     smooth_window,
    #     "Price Abs Log Return",
    #     f"Trend Abs Log Return({trend})",
    #     f"H1 {year}: {coin_name} Price Abs Log Return vs Trend Abs Log Return (rolling window={smooth_window})",
    # )
    # analyser.plot_smoothed(
    #     "H2",
    #     "abs_log_return",
    #     "abs_trend_log_return",
    #     smooth_window,
    #     "Price Abs Log Return",
    #     f"Trend Abs Log Return ({trend})",
    #     f"H2 {year}: {coin_name} Price Abs Log Return vs Trend Abs Log Return (rolling window={smooth_window})",
    # )
# Out:
# === Testing Granger causality up to lag=3 in 2021 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.1175  , p=0.1474  , df_denom=176, df_num=1
# ssr based chi2 test:   chi2=2.1536  , p=0.1422  , df=1
# likelihood ratio test: chi2=2.1407  , p=0.1434  , df=1
# parameter F test:         F=2.1175  , p=0.1474  , df_denom=176, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4838  , p=0.2296  , df_denom=173, df_num=2
# ssr based chi2 test:   chi2=3.0533  , p=0.2173  , df=2
# likelihood ratio test: chi2=3.0274  , p=0.2201  , df=2
# parameter F test:         F=1.4838  , p=0.2296  , df_denom=173, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3808  , p=0.2504  , df_denom=170, df_num=3
# ssr based chi2 test:   chi2=4.3129  , p=0.2296  , df=3
# likelihood ratio test: chi2=4.2612  , p=0.2346  , df=3
# parameter F test:         F=1.3808  , p=0.2504  , df_denom=170, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3923  , p=0.5319  , df_denom=176, df_num=1
# ssr based chi2 test:   chi2=0.3990  , p=0.5276  , df=1
# likelihood ratio test: chi2=0.3985  , p=0.5279  , df=1
# parameter F test:         F=0.3923  , p=0.5319  , df_denom=176, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3440  , p=0.7094  , df_denom=173, df_num=2
# ssr based chi2 test:   chi2=0.7079  , p=0.7019  , df=2
# likelihood ratio test: chi2=0.7065  , p=0.7024  , df=2
# parameter F test:         F=0.3440  , p=0.7094  , df_denom=173, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5775  , p=0.6306  , df_denom=170, df_num=3
# ssr based chi2 test:   chi2=1.8037  , p=0.6141  , df=3
# likelihood ratio test: chi2=1.7946  , p=0.6161  , df=3
# parameter F test:         F=0.5775  , p=0.6306  , df_denom=170, df_num=3
#
# === Testing Granger causality up to lag=3 in 2022 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4972  , p=0.4817  , df_denom=176, df_num=1
# ssr based chi2 test:   chi2=0.5057  , p=0.4770  , df=1
# likelihood ratio test: chi2=0.5050  , p=0.4773  , df=1
# parameter F test:         F=0.4972  , p=0.4817  , df_denom=176, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3244  , p=0.7234  , df_denom=173, df_num=2
# ssr based chi2 test:   chi2=0.6675  , p=0.7162  , df=2
# likelihood ratio test: chi2=0.6663  , p=0.7167  , df=2
# parameter F test:         F=0.3244  , p=0.7234  , df_denom=173, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.5397  , p=0.2061  , df_denom=170, df_num=3
# ssr based chi2 test:   chi2=4.8094  , p=0.1863  , df=3
# likelihood ratio test: chi2=4.7452  , p=0.1914  , df=3
# parameter F test:         F=1.5397  , p=0.2061  , df_denom=170, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.4921  , p=0.0633  , df_denom=176, df_num=1
# ssr based chi2 test:   chi2=3.5516  , p=0.0595  , df=1
# likelihood ratio test: chi2=3.5168  , p=0.0607  , df=1
# parameter F test:         F=3.4921  , p=0.0633  , df_denom=176, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.7821  , p=0.0095  , df_denom=173, df_num=2
# ssr based chi2 test:   chi2=9.8405  , p=0.0073  , df=2
# likelihood ratio test: chi2=9.5782  , p=0.0083  , df=2
# parameter F test:         F=4.7821  , p=0.0095  , df_denom=173, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.5816  , p=0.0011  , df_denom=170, df_num=3
# ssr based chi2 test:   chi2=17.4342 , p=0.0006  , df=3
# likelihood ratio test: chi2=16.6281 , p=0.0008  , df=3
# parameter F test:         F=5.5816  , p=0.0011  , df_denom=170, df_num=3
#
# === Testing Granger causality up to lag=3 in 2023 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0312  , p=0.8599  , df_denom=176, df_num=1
# ssr based chi2 test:   chi2=0.0318  , p=0.8585  , df=1
# likelihood ratio test: chi2=0.0318  , p=0.8585  , df=1
# parameter F test:         F=0.0312  , p=0.8599  , df_denom=176, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7952  , p=0.4531  , df_denom=173, df_num=2
# ssr based chi2 test:   chi2=1.6364  , p=0.4412  , df=2
# likelihood ratio test: chi2=1.6289  , p=0.4429  , df=2
# parameter F test:         F=0.7952  , p=0.4531  , df_denom=173, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5534  , p=0.6465  , df_denom=170, df_num=3
# ssr based chi2 test:   chi2=1.7285  , p=0.6306  , df=3
# likelihood ratio test: chi2=1.7201  , p=0.6325  , df=3
# parameter F test:         F=0.5534  , p=0.6465  , df_denom=170, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=14.1588 , p=0.0002  , df_denom=176, df_num=1
# ssr based chi2 test:   chi2=14.4001 , p=0.0001  , df=1
# likelihood ratio test: chi2=13.8502 , p=0.0002  , df=1
# parameter F test:         F=14.1588 , p=0.0002  , df_denom=176, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.7574  , p=0.0006  , df_denom=173, df_num=2
# ssr based chi2 test:   chi2=15.9633 , p=0.0003  , df=2
# likelihood ratio test: chi2=15.2876 , p=0.0005  , df=2
# parameter F test:         F=7.7574  , p=0.0006  , df_denom=173, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.8948  , p=0.0008  , df_denom=170, df_num=3
# ssr based chi2 test:   chi2=18.4125 , p=0.0004  , df=3
# likelihood ratio test: chi2=17.5164 , p=0.0006  , df=3
# parameter F test:         F=5.8948  , p=0.0008  , df_denom=170, df_num=3
#
# === Testing Granger causality up to lag=3 in 2024 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5918  , p=0.4428  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=0.6018  , p=0.4379  , df=1
# likelihood ratio test: chi2=0.6008  , p=0.4383  , df=1
# parameter F test:         F=0.5918  , p=0.4428  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2516  , p=0.7778  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=0.5177  , p=0.7719  , df=2
# likelihood ratio test: chi2=0.5170  , p=0.7722  , df=2
# parameter F test:         F=0.2516  , p=0.7778  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1775  , p=0.9115  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=0.5543  , p=0.9068  , df=3
# likelihood ratio test: chi2=0.5535  , p=0.9070  , df=3
# parameter F test:         F=0.1775  , p=0.9115  , df_denom=171, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.6831  , p=0.0566  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=3.7455  , p=0.0530  , df=1
# likelihood ratio test: chi2=3.7070  , p=0.0542  , df=1
# parameter F test:         F=3.6831  , p=0.0566  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.1348  , p=0.1214  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=4.3923  , p=0.1112  , df=2
# likelihood ratio test: chi2=4.3393  , p=0.1142  , df=2
# parameter F test:         F=2.1348  , p=0.1214  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.5014  , p=0.2160  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=4.6886  , p=0.1961  , df=3
# likelihood ratio test: chi2=4.6280  , p=0.2012  , df=3
# parameter F test:         F=1.5014  , p=0.2160  , df_denom=171, df_num=3
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import grangercausalitytests
from nodiensenv.constants import DATA_DIR, FIGURE_DIR
from nodiensenv.analyser import TrendPriceAnalyser

years = [2021, 2022, 2023, 2024]

for year in years:
    trend = "bitcoin"
    coin_name = "BTC"
    trend_h1 = pd.read_csv(
        DATA_DIR / f"trend_{coin_name}_{year}_H1.csv", parse_dates=["date"]
    )
    trend_h2 = pd.read_csv(
        DATA_DIR / f"trend_{coin_name}_{year}_H2.csv", parse_dates=["date"]
    )
    price = pd.read_csv(DATA_DIR / f"{coin_name}_price_mcap.csv", parse_dates=["date"])

    # Filter price to {year}, split H1 & H2, and compute daily log-returns
    price_year = price[price["date"].dt.year == year].sort_values("date")
    price_h1 = price_year[(price_year["date"] <= f"{year}-06-30")].copy()
    price_h2 = price_year[(price_year["date"] >= f"{year}-07-01")].copy()

    for df in (price_h1, price_h2):
        df["log_return"] = np.log(df["close"] / df["close"].shift(1)) * 100
        df["abs_log_return"] = abs(df["log_return"])

    for df in (trend_h1, trend_h2):
        df["trend_log_return"] = np.log(df[f"{trend}"] / df[f"{trend}"].shift(1)) * 100
        df["abs_trend_log_return"] = abs(df["trend_log_return"])

    # Merge each half’s trends with its prices
    df_h1 = pd.merge(
        trend_h1,
        price_h1[["date", "close", "log_return", "abs_log_return"]],
        on="date",
        how="inner",
    )
    df_h2 = pd.merge(
        trend_h2,
        price_h2[["date", "close", "log_return", "abs_log_return"]],
        on="date",
        how="inner",
    )

    # series_price_h1 = df_h1[["log_return"]].dropna()
    # series_trend_h1 = df_h1[["trend_log_return"]].dropna()
    series_price_h1 = df_h1[["close"]].dropna()
    series_trend_h1 = df_h1[[f"{trend}"]].dropna()
    df_gc = pd.concat([series_price_h1, series_trend_h1], axis=1).dropna()
    df_gc.columns = ["price_ret", "trend_ret"]

    # Runs Granger tests up to `max_lag` for both directions:
    #     1) Does trend --> price?
    #     2) Does price --> trend?

    def run_granger(df, max_lag):
        print(f"\n=== Testing Granger causality up to lag={max_lag} in {year} ===\n")

        # 3a) trend --> price
        print(">> Does TREND Granger-cause PRICE?")
        test_result_1 = grangercausalitytests(
            df[["price_ret", "trend_ret"]], maxlag=max_lag, verbose=True
        )
        # 3b) price --> trend
        print("\n>> Does PRICE Granger-cause TREND?")
        test_result_2 = grangercausalitytests(
            df[["trend_ret", "price_ret"]], maxlag=max_lag, verbose=True
        )

        return test_result_1, test_result_2

    res_trend_to_price, res_price_to_trend = run_granger(df_gc, max_lag=3)

    # analyser = TrendPriceAnalyser(trend, df_h1, df_h2)

    # for smooth_window in [3]:
    #         analyser.plot_smoothed(
    #             "H1",
    #             "close",
    #             f"{trend}",
    #             smooth_window,
    #             "Close Price",
    #             f"Google Trend ({trend})",
    #             f"H1 {year}: {coin_name} Close vs Trend (rolling window={smooth_window})",
    #         )
    #         analyser.plot_smoothed(
    #             "H2",
    #             "close",
    #             f"{trend}",
    #             smooth_window,
    #             "Close Price",
    #             f"Google Trend ({trend})",
    #             f"H2 {year}: {coin_name} Close vs Trend (rolling window={smooth_window})",
    #         )
    #     analyser.plot_smoothed(
    #         "H1",
    #         "log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H1 {year}: {coin_name} Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H2",
    #         "log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H2 {year}: {coin_name} Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H1",
    #         "abs_log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H1 {year}: {coin_name} abs Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H2",
    #         "abs_log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H2 {year}: {coin_name} abs Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H1",
    #         "log_return",
    #         "trend_log_return",
    #         smooth_window,
    #         "Price Log Return",
    #         "Trend Log Return",
    #         f"H1 {year}: {coin_name} Price Log Return vs Trend Log Return (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H2",
    #         "log_return",
    #         "trend_log_return",
    #         smooth_window,
    #         "Price Log Return",
    #         "Trend Log Return",
    #         f"H2 {year}: {coin_name} Price Log Return vs Trend Log Return (rolling window={smooth_window})",
    #     )
    # analyser.plot_smoothed(
    #     "H1",
    #     "abs_log_return",
    #     "abs_trend_log_return",
    #     smooth_window,
    #     "Price Abs Log Return",
    #     f"Trend Abs Log Return({trend})",
    #     f"H1 {year}: {coin_name} Price Abs Log Return vs Trend Abs Log Return (rolling window={smooth_window})",
    # )
    # analyser.plot_smoothed(
    #     "H2",
    #     "abs_log_return",
    #     "abs_trend_log_return",
    #     smooth_window,
    #     "Price Abs Log Return",
    #     f"Trend Abs Log Return ({trend})",
    #     f"H2 {year}: {coin_name} Price Abs Log Return vs Trend Abs Log Return (rolling window={smooth_window})",
    # )
# Out:
# === Testing Granger causality up to lag=3 in 2021 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3619  , p=0.5482  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=0.3680  , p=0.5441  , df=1
# likelihood ratio test: chi2=0.3677  , p=0.5443  , df=1
# parameter F test:         F=0.3619  , p=0.5482  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.9772  , p=0.1416  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=4.0679  , p=0.1308  , df=2
# likelihood ratio test: chi2=4.0224  , p=0.1338  , df=2
# parameter F test:         F=1.9772  , p=0.1416  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4000  , p=0.2446  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=4.3718  , p=0.2240  , df=3
# likelihood ratio test: chi2=4.3190  , p=0.2290  , df=3
# parameter F test:         F=1.4000  , p=0.2446  , df_denom=171, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2579  , p=0.6122  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=0.2623  , p=0.6085  , df=1
# likelihood ratio test: chi2=0.2621  , p=0.6087  , df=1
# parameter F test:         F=0.2579  , p=0.6122  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3972  , p=0.6728  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=0.8172  , p=0.6646  , df=2
# likelihood ratio test: chi2=0.8154  , p=0.6652  , df=2
# parameter F test:         F=0.3972  , p=0.6728  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4094  , p=0.7465  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=1.2783  , p=0.7343  , df=3
# likelihood ratio test: chi2=1.2738  , p=0.7354  , df=3
# parameter F test:         F=0.4094  , p=0.7465  , df_denom=171, df_num=3
#
# === Testing Granger causality up to lag=3 in 2022 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3875  , p=0.5344  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=0.3940  , p=0.5302  , df=1
# likelihood ratio test: chi2=0.3936  , p=0.5304  , df=1
# parameter F test:         F=0.3875  , p=0.5344  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3279  , p=0.7209  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=0.6746  , p=0.7137  , df=2
# likelihood ratio test: chi2=0.6733  , p=0.7142  , df=2
# parameter F test:         F=0.3279  , p=0.7209  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2215  , p=0.8814  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=0.6918  , p=0.8751  , df=3
# likelihood ratio test: chi2=0.6904  , p=0.8755  , df=3
# parameter F test:         F=0.2215  , p=0.8814  , df_denom=171, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.8599  , p=0.0288  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=4.9423  , p=0.0262  , df=1
# likelihood ratio test: chi2=4.8756  , p=0.0272  , df=1
# parameter F test:         F=4.8599  , p=0.0288  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.2809  , p=0.1052  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=4.6930  , p=0.0957  , df=2
# likelihood ratio test: chi2=4.6325  , p=0.0986  , df=2
# parameter F test:         F=2.2809  , p=0.1052  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.7192  , p=0.0462  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=8.4916  , p=0.0369  , df=3
# likelihood ratio test: chi2=8.2953  , p=0.0403  , df=3
# parameter F test:         F=2.7192  , p=0.0462  , df_denom=171, df_num=3
#
# === Testing Granger causality up to lag=3 in 2023 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.5843  , p=0.1097  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=2.6281  , p=0.1050  , df=1
# likelihood ratio test: chi2=2.6091  , p=0.1063  , df=1
# parameter F test:         F=2.5843  , p=0.1097  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5023  , p=0.2255  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=3.0910  , p=0.2132  , df=2
# likelihood ratio test: chi2=3.0646  , p=0.2160  , df=2
# parameter F test:         F=1.5023  , p=0.2255  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6290  , p=0.5972  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=1.9642  , p=0.5799  , df=3
# likelihood ratio test: chi2=1.9534  , p=0.5821  , df=3
# parameter F test:         F=0.6290  , p=0.5972  , df_denom=171, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0071  , p=0.9330  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=0.0072  , p=0.9323  , df=1
# likelihood ratio test: chi2=0.0072  , p=0.9323  , df=1
# parameter F test:         F=0.0071  , p=0.9330  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=12.2792 , p=0.0000  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=25.2640 , p=0.0000  , df=2
# likelihood ratio test: chi2=23.6330 , p=0.0000  , df=2
# parameter F test:         F=12.2792 , p=0.0000  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=8.8686  , p=0.0000  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=27.6948 , p=0.0000  , df=3
# likelihood ratio test: chi2=25.7406 , p=0.0000  , df=3
# parameter F test:         F=8.8686  , p=0.0000  , df_denom=171, df_num=3
#
# === Testing Granger causality up to lag=3 in 2024 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1797  , p=0.6721  , df_denom=178, df_num=1
# ssr based chi2 test:   chi2=0.1828  , p=0.6690  , df=1
# likelihood ratio test: chi2=0.1827  , p=0.6691  , df=1
# parameter F test:         F=0.1797  , p=0.6721  , df_denom=178, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4988  , p=0.6081  , df_denom=175, df_num=2
# ssr based chi2 test:   chi2=1.0262  , p=0.5986  , df=2
# likelihood ratio test: chi2=1.0232  , p=0.5995  , df=2
# parameter F test:         F=0.4988  , p=0.6081  , df_denom=175, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3033  , p=0.8229  , df_denom=172, df_num=3
# ssr based chi2 test:   chi2=0.9471  , p=0.8141  , df=3
# likelihood ratio test: chi2=0.9446  , p=0.8147  , df=3
# parameter F test:         F=0.3033  , p=0.8229  , df_denom=172, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0584  , p=0.8094  , df_denom=178, df_num=1
# ssr based chi2 test:   chi2=0.0593  , p=0.8076  , df=1
# likelihood ratio test: chi2=0.0593  , p=0.8076  , df=1
# parameter F test:         F=0.0584  , p=0.8094  , df_denom=178, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3031  , p=0.1030  , df_denom=175, df_num=2
# ssr based chi2 test:   chi2=4.7379  , p=0.0936  , df=2
# likelihood ratio test: chi2=4.6766  , p=0.0965  , df=2
# parameter F test:         F=2.3031  , p=0.1030  , df_denom=175, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2319  , p=0.2997  , df_denom=172, df_num=3
# ssr based chi2 test:   chi2=3.8462  , p=0.2786  , df=3
# likelihood ratio test: chi2=3.8055  , p=0.2832  , df=3
# parameter F test:         F=1.2319  , p=0.2997  , df_denom=172, df_num=3
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import grangercausalitytests
from nodiensenv.constants import DATA_DIR, FIGURE_DIR
from nodiensenv.analyser import TrendPriceAnalyser

years = [2021, 2022, 2023, 2024]

for year in years:
    trend = "bitcoin"
    coin_name = "BTC"
    trend_h1 = pd.read_csv(
        DATA_DIR / f"trend_{coin_name}_{year}_H1.csv", parse_dates=["date"]
    )
    trend_h2 = pd.read_csv(
        DATA_DIR / f"trend_{coin_name}_{year}_H2.csv", parse_dates=["date"]
    )
    price = pd.read_csv(DATA_DIR / f"{coin_name}_price_mcap.csv", parse_dates=["date"])

    # Filter price to {year}, split H1 & H2, and compute daily log-returns
    price_year = price[price["date"].dt.year == year].sort_values("date")
    price_h1 = price_year[(price_year["date"] <= f"{year}-06-30")].copy()
    price_h2 = price_year[(price_year["date"] >= f"{year}-07-01")].copy()

    for df in (price_h1, price_h2):
        df["log_return"] = np.log(df["close"] / df["close"].shift(1)) * 100
        df["abs_log_return"] = abs(df["log_return"])

    for df in (trend_h1, trend_h2):
        df["trend_log_return"] = np.log(df[f"{trend}"] / df[f"{trend}"].shift(1)) * 100
        df["abs_trend_log_return"] = abs(df["trend_log_return"])

    # Merge each half’s trends with its prices
    df_h1 = pd.merge(
        trend_h1,
        price_h1[["date", "close", "log_return", "abs_log_return"]],
        on="date",
        how="inner",
    )
    df_h2 = pd.merge(
        trend_h2,
        price_h2[["date", "close", "log_return", "abs_log_return"]],
        on="date",
        how="inner",
    )

    # series_price_h1 = df_h1[["log_return"]].dropna()
    # series_trend_h1 = df_h1[["trend_log_return"]].dropna()
    series_price_h1 = df_h1[["close"]].dropna()
    series_trend_h1 = df_h1[[f"{trend}"]].dropna()
    df_gc_h1 = pd.concat([series_price_h1, series_trend_h1], axis=1).dropna()
    df_gc_h1.columns = ["price_ret", "trend_ret"]

    series_price_h2 = df_h2[["close"]].dropna()
    series_trend_h2 = df_h2[[f"{trend}"]].dropna()
    df_gc_h2 = pd.concat([series_price_h2, series_trend_h2], axis=1).dropna()
    df_gc_h2.columns = ["price_ret", "trend_ret"]

    # Runs Granger tests up to `max_lag` for both directions:
    #     1) Does trend --> price?
    #     2) Does price --> trend?

    def run_granger(df, max_lag):
        print(f"\n=== Testing Granger causality up to lag={max_lag} in {year} ===\n")

        # 3a) trend --> price
        print(">> Does TREND Granger-cause PRICE?")
        test_result_1 = grangercausalitytests(
            df[["price_ret", "trend_ret"]], maxlag=max_lag, verbose=True
        )
        # 3b) price --> trend
        print("\n>> Does PRICE Granger-cause TREND?")
        test_result_2 = grangercausalitytests(
            df[["trend_ret", "price_ret"]], maxlag=max_lag, verbose=True
        )

        return test_result_1, test_result_2

    res_trend_to_price, res_price_to_trend = run_granger(df_gc_h1, max_lag=3)
    res_trend_to_price, res_price_to_trend = run_granger(df_gc_h2, max_lag=3)

    # analyser = TrendPriceAnalyser(trend, df_h1, df_h2)

    # for smooth_window in [3]:
    #         analyser.plot_smoothed(
    #             "H1",
    #             "close",
    #             f"{trend}",
    #             smooth_window,
    #             "Close Price",
    #             f"Google Trend ({trend})",
    #             f"H1 {year}: {coin_name} Close vs Trend (rolling window={smooth_window})",
    #         )
    #         analyser.plot_smoothed(
    #             "H2",
    #             "close",
    #             f"{trend}",
    #             smooth_window,
    #             "Close Price",
    #             f"Google Trend ({trend})",
    #             f"H2 {year}: {coin_name} Close vs Trend (rolling window={smooth_window})",
    #         )
    #     analyser.plot_smoothed(
    #         "H1",
    #         "log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H1 {year}: {coin_name} Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H2",
    #         "log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H2 {year}: {coin_name} Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H1",
    #         "abs_log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H1 {year}: {coin_name} abs Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H2",
    #         "abs_log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H2 {year}: {coin_name} abs Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H1",
    #         "log_return",
    #         "trend_log_return",
    #         smooth_window,
    #         "Price Log Return",
    #         "Trend Log Return",
    #         f"H1 {year}: {coin_name} Price Log Return vs Trend Log Return (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H2",
    #         "log_return",
    #         "trend_log_return",
    #         smooth_window,
    #         "Price Log Return",
    #         "Trend Log Return",
    #         f"H2 {year}: {coin_name} Price Log Return vs Trend Log Return (rolling window={smooth_window})",
    #     )
    # analyser.plot_smoothed(
    #     "H1",
    #     "abs_log_return",
    #     "abs_trend_log_return",
    #     smooth_window,
    #     "Price Abs Log Return",
    #     f"Trend Abs Log Return({trend})",
    #     f"H1 {year}: {coin_name} Price Abs Log Return vs Trend Abs Log Return (rolling window={smooth_window})",
    # )
    # analyser.plot_smoothed(
    #     "H2",
    #     "abs_log_return",
    #     "abs_trend_log_return",
    #     smooth_window,
    #     "Price Abs Log Return",
    #     f"Trend Abs Log Return ({trend})",
    #     f"H2 {year}: {coin_name} Price Abs Log Return vs Trend Abs Log Return (rolling window={smooth_window})",
    # )
# Out:
# === Testing Granger causality up to lag=3 in 2021 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3619  , p=0.5482  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=0.3680  , p=0.5441  , df=1
# likelihood ratio test: chi2=0.3677  , p=0.5443  , df=1
# parameter F test:         F=0.3619  , p=0.5482  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.9772  , p=0.1416  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=4.0679  , p=0.1308  , df=2
# likelihood ratio test: chi2=4.0224  , p=0.1338  , df=2
# parameter F test:         F=1.9772  , p=0.1416  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4000  , p=0.2446  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=4.3718  , p=0.2240  , df=3
# likelihood ratio test: chi2=4.3190  , p=0.2290  , df=3
# parameter F test:         F=1.4000  , p=0.2446  , df_denom=171, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2579  , p=0.6122  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=0.2623  , p=0.6085  , df=1
# likelihood ratio test: chi2=0.2621  , p=0.6087  , df=1
# parameter F test:         F=0.2579  , p=0.6122  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3972  , p=0.6728  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=0.8172  , p=0.6646  , df=2
# likelihood ratio test: chi2=0.8154  , p=0.6652  , df=2
# parameter F test:         F=0.3972  , p=0.6728  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4094  , p=0.7465  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=1.2783  , p=0.7343  , df=3
# likelihood ratio test: chi2=1.2738  , p=0.7354  , df=3
# parameter F test:         F=0.4094  , p=0.7465  , df_denom=171, df_num=3
#
# === Testing Granger causality up to lag=3 in 2021 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0041  , p=0.9490  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=0.0042  , p=0.9485  , df=1
# likelihood ratio test: chi2=0.0042  , p=0.9485  , df=1
# parameter F test:         F=0.0041  , p=0.9490  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1163  , p=0.8903  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=0.2392  , p=0.8873  , df=2
# likelihood ratio test: chi2=0.2390  , p=0.8873  , df=2
# parameter F test:         F=0.1163  , p=0.8903  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1236  , p=0.9461  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=0.3856  , p=0.9432  , df=3
# likelihood ratio test: chi2=0.3852  , p=0.9433  , df=3
# parameter F test:         F=0.1236  , p=0.9461  , df_denom=174, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.0519  , p=0.0051  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=8.1861  , p=0.0042  , df=1
# likelihood ratio test: chi2=8.0083  , p=0.0047  , df=1
# parameter F test:         F=8.0519  , p=0.0051  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.7845  , p=0.0095  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=9.8393  , p=0.0073  , df=2
# likelihood ratio test: chi2=9.5825  , p=0.0083  , df=2
# parameter F test:         F=4.7845  , p=0.0095  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.8214  , p=0.0110  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=11.9255 , p=0.0076  , df=3
# likelihood ratio test: chi2=11.5491 , p=0.0091  , df=3
# parameter F test:         F=3.8214  , p=0.0110  , df_denom=174, df_num=3
#
# === Testing Granger causality up to lag=3 in 2022 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3875  , p=0.5344  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=0.3940  , p=0.5302  , df=1
# likelihood ratio test: chi2=0.3936  , p=0.5304  , df=1
# parameter F test:         F=0.3875  , p=0.5344  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3279  , p=0.7209  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=0.6746  , p=0.7137  , df=2
# likelihood ratio test: chi2=0.6733  , p=0.7142  , df=2
# parameter F test:         F=0.3279  , p=0.7209  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2215  , p=0.8814  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=0.6918  , p=0.8751  , df=3
# likelihood ratio test: chi2=0.6904  , p=0.8755  , df=3
# parameter F test:         F=0.2215  , p=0.8814  , df_denom=171, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.8599  , p=0.0288  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=4.9423  , p=0.0262  , df=1
# likelihood ratio test: chi2=4.8756  , p=0.0272  , df=1
# parameter F test:         F=4.8599  , p=0.0288  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.2809  , p=0.1052  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=4.6930  , p=0.0957  , df=2
# likelihood ratio test: chi2=4.6325  , p=0.0986  , df=2
# parameter F test:         F=2.2809  , p=0.1052  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.7192  , p=0.0462  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=8.4916  , p=0.0369  , df=3
# likelihood ratio test: chi2=8.2953  , p=0.0403  , df=3
# parameter F test:         F=2.7192  , p=0.0462  , df_denom=171, df_num=3
#
# === Testing Granger causality up to lag=3 in 2022 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.0621  , p=0.1527  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=2.0965  , p=0.1476  , df=1
# likelihood ratio test: chi2=2.0846  , p=0.1488  , df=1
# parameter F test:         F=2.0621  , p=0.1527  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1013  , p=0.3347  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=2.2648  , p=0.3223  , df=2
# likelihood ratio test: chi2=2.2508  , p=0.3245  , df=2
# parameter F test:         F=1.1013  , p=0.3347  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8141  , p=0.4877  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=2.5406  , p=0.4680  , df=3
# likelihood ratio test: chi2=2.5229  , p=0.4712  , df=3
# parameter F test:         F=0.8141  , p=0.4877  , df_denom=174, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4458  , p=0.5052  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=0.4533  , p=0.5008  , df=1
# likelihood ratio test: chi2=0.4527  , p=0.5011  , df=1
# parameter F test:         F=0.4458  , p=0.5052  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.7700  , p=0.0015  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=13.9226 , p=0.0009  , df=2
# likelihood ratio test: chi2=13.4157 , p=0.0012  , df=2
# parameter F test:         F=6.7700  , p=0.0015  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.2050  , p=0.0067  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=13.1224 , p=0.0044  , df=3
# likelihood ratio test: chi2=12.6685 , p=0.0054  , df=3
# parameter F test:         F=4.2050  , p=0.0067  , df_denom=174, df_num=3
#
# === Testing Granger causality up to lag=3 in 2023 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.5843  , p=0.1097  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=2.6281  , p=0.1050  , df=1
# likelihood ratio test: chi2=2.6091  , p=0.1063  , df=1
# parameter F test:         F=2.5843  , p=0.1097  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5023  , p=0.2255  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=3.0910  , p=0.2132  , df=2
# likelihood ratio test: chi2=3.0646  , p=0.2160  , df=2
# parameter F test:         F=1.5023  , p=0.2255  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6290  , p=0.5972  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=1.9642  , p=0.5799  , df=3
# likelihood ratio test: chi2=1.9534  , p=0.5821  , df=3
# parameter F test:         F=0.6290  , p=0.5972  , df_denom=171, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0071  , p=0.9330  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=0.0072  , p=0.9323  , df=1
# likelihood ratio test: chi2=0.0072  , p=0.9323  , df=1
# parameter F test:         F=0.0071  , p=0.9330  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=12.2792 , p=0.0000  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=25.2640 , p=0.0000  , df=2
# likelihood ratio test: chi2=23.6330 , p=0.0000  , df=2
# parameter F test:         F=12.2792 , p=0.0000  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=8.8686  , p=0.0000  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=27.6948 , p=0.0000  , df=3
# likelihood ratio test: chi2=25.7406 , p=0.0000  , df=3
# parameter F test:         F=8.8686  , p=0.0000  , df_denom=171, df_num=3
#
# === Testing Granger causality up to lag=3 in 2023 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.2292  , p=0.2690  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=1.2497  , p=0.2636  , df=1
# likelihood ratio test: chi2=1.2454  , p=0.2644  , df=1
# parameter F test:         F=1.2292  , p=0.2690  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.6145  , p=0.0760  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=5.3766  , p=0.0680  , df=2
# likelihood ratio test: chi2=5.2987  , p=0.0707  , df=2
# parameter F test:         F=2.6145  , p=0.0760  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2735  , p=0.0818  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=7.0950  , p=0.0689  , df=3
# likelihood ratio test: chi2=6.9595  , p=0.0732  , df=3
# parameter F test:         F=2.2735  , p=0.0818  , df_denom=174, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=14.6368 , p=0.0002  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=14.8807 , p=0.0001  , df=1
# likelihood ratio test: chi2=14.3066 , p=0.0002  , df=1
# parameter F test:         F=14.6368 , p=0.0002  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=13.6803 , p=0.0000  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=28.1335 , p=0.0000  , df=2
# likelihood ratio test: chi2=26.1600 , p=0.0000  , df=2
# parameter F test:         F=13.6803 , p=0.0000  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=8.5112  , p=0.0000  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=26.5607 , p=0.0000  , df=3
# likelihood ratio test: chi2=24.7837 , p=0.0000  , df=3
# parameter F test:         F=8.5112  , p=0.0000  , df_denom=174, df_num=3
#
# === Testing Granger causality up to lag=3 in 2024 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1797  , p=0.6721  , df_denom=178, df_num=1
# ssr based chi2 test:   chi2=0.1828  , p=0.6690  , df=1
# likelihood ratio test: chi2=0.1827  , p=0.6691  , df=1
# parameter F test:         F=0.1797  , p=0.6721  , df_denom=178, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4988  , p=0.6081  , df_denom=175, df_num=2
# ssr based chi2 test:   chi2=1.0262  , p=0.5986  , df=2
# likelihood ratio test: chi2=1.0232  , p=0.5995  , df=2
# parameter F test:         F=0.4988  , p=0.6081  , df_denom=175, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3033  , p=0.8229  , df_denom=172, df_num=3
# ssr based chi2 test:   chi2=0.9471  , p=0.8141  , df=3
# likelihood ratio test: chi2=0.9446  , p=0.8147  , df=3
# parameter F test:         F=0.3033  , p=0.8229  , df_denom=172, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0584  , p=0.8094  , df_denom=178, df_num=1
# ssr based chi2 test:   chi2=0.0593  , p=0.8076  , df=1
# likelihood ratio test: chi2=0.0593  , p=0.8076  , df=1
# parameter F test:         F=0.0584  , p=0.8094  , df_denom=178, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3031  , p=0.1030  , df_denom=175, df_num=2
# ssr based chi2 test:   chi2=4.7379  , p=0.0936  , df=2
# likelihood ratio test: chi2=4.6766  , p=0.0965  , df=2
# parameter F test:         F=2.3031  , p=0.1030  , df_denom=175, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2319  , p=0.2997  , df_denom=172, df_num=3
# ssr based chi2 test:   chi2=3.8462  , p=0.2786  , df=3
# likelihood ratio test: chi2=3.8055  , p=0.2832  , df=3
# parameter F test:         F=1.2319  , p=0.2997  , df_denom=172, df_num=3
#
# === Testing Granger causality up to lag=3 in 2024 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.4500  , p=0.0363  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=4.5242  , p=0.0334  , df=1
# likelihood ratio test: chi2=4.4692  , p=0.0345  , df=1
# parameter F test:         F=4.4500  , p=0.0363  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.0122  , p=0.0517  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=6.1946  , p=0.0452  , df=2
# likelihood ratio test: chi2=6.0915  , p=0.0476  , df=2
# parameter F test:         F=3.0122  , p=0.0517  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.6820  , p=0.0484  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=8.3696  , p=0.0390  , df=3
# likelihood ratio test: chi2=8.1819  , p=0.0424  , df=3
# parameter F test:         F=2.6820  , p=0.0484  , df_denom=174, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=16.8733 , p=0.0001  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=17.1545 , p=0.0000  , df=1
# likelihood ratio test: chi2=16.3975 , p=0.0001  , df=1
# parameter F test:         F=16.8733 , p=0.0001  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=9.0107  , p=0.0002  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=18.5305 , p=0.0001  , df=2
# likelihood ratio test: chi2=17.6466 , p=0.0001  , df=2
# parameter F test:         F=9.0107  , p=0.0002  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.2042  , p=0.0018  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=16.2406 , p=0.0010  , df=3
# likelihood ratio test: chi2=15.5529 , p=0.0014  , df=3
# parameter F test:         F=5.2042  , p=0.0018  , df_denom=174, df_num=3
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import grangercausalitytests
from nodiensenv.constants import DATA_DIR, FIGURE_DIR
from nodiensenv.analyser import TrendPriceAnalyser

years = [2021, 2022, 2023, 2024]

for year in years:
    trend = "bitcoin"
    coin_name = "BTC"
    trend_h1 = pd.read_csv(
        DATA_DIR / f"trend_{coin_name}_{year}_H1.csv", parse_dates=["date"]
    )
    trend_h2 = pd.read_csv(
        DATA_DIR / f"trend_{coin_name}_{year}_H2.csv", parse_dates=["date"]
    )
    price = pd.read_csv(DATA_DIR / f"{coin_name}_price_mcap.csv", parse_dates=["date"])

    # Filter price to {year}, split H1 & H2, and compute daily log-returns
    price_year = price[price["date"].dt.year == year].sort_values("date")
    price_h1 = price_year[(price_year["date"] <= f"{year}-06-30")].copy()
    price_h2 = price_year[(price_year["date"] >= f"{year}-07-01")].copy()

    for df in (price_h1, price_h2):
        df["log_return"] = np.log(df["close"] / df["close"].shift(1)) * 100
        df["abs_log_return"] = abs(df["log_return"])

    for df in (trend_h1, trend_h2):
        df["trend_log_return"] = np.log(df[f"{trend}"] / df[f"{trend}"].shift(1)) * 100
        df["abs_trend_log_return"] = abs(df["trend_log_return"])

    # Merge each half’s trends with its prices
    df_h1 = pd.merge(
        trend_h1,
        price_h1[["date", "close", "log_return", "abs_log_return"]],
        on="date",
        how="inner",
    )
    df_h2 = pd.merge(
        trend_h2,
        price_h2[["date", "close", "log_return", "abs_log_return"]],
        on="date",
        how="inner",
    )

    def run_granger(df, max_lag):
        print(f"\n=== Testing Granger causality up to lag={max_lag} in {year} ===\n")

        # 3a) trend --> price
        print(">> Does TREND Granger-cause PRICE?")
        test_result_1 = grangercausalitytests(
            df[["price_ret", "trend_ret"]], maxlag=max_lag, verbose=True
        )
        # 3b) price --> trend
        print("\n>> Does PRICE Granger-cause TREND?")
        test_result_2 = grangercausalitytests(
            df[["trend_ret", "price_ret"]], maxlag=max_lag, verbose=True
        )

        return test_result_1, test_result_2

    # series_price_h1 = df_h1[["log_return"]].dropna()
    # series_trend_h1 = df_h1[["trend_log_return"]].dropna()

    for h in ("H1", "H2"):
        df = df_h1 if h == "H1" else df_h2
        series_price = df[["close"]].dropna()
        series_trend = df[[f"{trend}"]].dropna()
        df_gc = pd.concat([series_price, series_trend], axis=1).dropna()
        df_gc.columns = ["price_ret", "trend_ret"]
        print(f"\nGranger causality results for {h} in {year}:")
        res_trend_to_price, res_price_to_trend = run_granger(df_gc, max_lag=3)


    # series_price_h1 = df_h1[["close"]].dropna()
    # series_trend_h1 = df_h1[[f"{trend}"]].dropna()
    # df_gc_h1 = pd.concat([series_price_h1, series_trend_h1], axis=1).dropna()
    # df_gc_h1.columns = ["price_ret", "trend_ret"]

    # series_price_h2 = df_h2[["close"]].dropna()
    # series_trend_h2 = df_h2[[f"{trend}"]].dropna()
    # df_gc_h2 = pd.concat([series_price_h2, series_trend_h2], axis=1).dropna()
    # df_gc_h2.columns = ["price_ret", "trend_ret"]

    # # Runs Granger tests up to `max_lag` for both directions:
    # #     1) Does trend --> price?
    # #     2) Does price --> trend?

    # def run_granger(df, max_lag):
    #     print(f"\n=== Testing Granger causality up to lag={max_lag} in {year} ===\n")

    #     # 3a) trend --> price
    #     print(">> Does TREND Granger-cause PRICE?")
    #     test_result_1 = grangercausalitytests(
    #         df[["price_ret", "trend_ret"]], maxlag=max_lag, verbose=True
    #     )
    #     # 3b) price --> trend
    #     print("\n>> Does PRICE Granger-cause TREND?")
    #     test_result_2 = grangercausalitytests(
    #         df[["trend_ret", "price_ret"]], maxlag=max_lag, verbose=True
    #     )

    #     return test_result_1, test_result_2

    # res_trend_to_price, res_price_to_trend = run_granger(df_gc_h1, max_lag=3)
    # res_trend_to_price, res_price_to_trend = run_granger(df_gc_h2, max_lag=3)

    # analyser = TrendPriceAnalyser(trend, df_h1, df_h2)

    # for smooth_window in [3]:
    #         analyser.plot_smoothed(
    #             "H1",
    #             "close",
    #             f"{trend}",
    #             smooth_window,
    #             "Close Price",
    #             f"Google Trend ({trend})",
    #             f"H1 {year}: {coin_name} Close vs Trend (rolling window={smooth_window})",
    #         )
    #         analyser.plot_smoothed(
    #             "H2",
    #             "close",
    #             f"{trend}",
    #             smooth_window,
    #             "Close Price",
    #             f"Google Trend ({trend})",
    #             f"H2 {year}: {coin_name} Close vs Trend (rolling window={smooth_window})",
    #         )
    #     analyser.plot_smoothed(
    #         "H1",
    #         "log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H1 {year}: {coin_name} Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H2",
    #         "log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H2 {year}: {coin_name} Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H1",
    #         "abs_log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H1 {year}: {coin_name} abs Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H2",
    #         "abs_log_return",
    #         f"{trend}",
    #         smooth_window,
    #         "Log Return",
    #         f"Google Trend ({trend})",
    #         f"H2 {year}: {coin_name} abs Log Return vs Trend (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H1",
    #         "log_return",
    #         "trend_log_return",
    #         smooth_window,
    #         "Price Log Return",
    #         "Trend Log Return",
    #         f"H1 {year}: {coin_name} Price Log Return vs Trend Log Return (rolling window={smooth_window})",
    #     )
    #     analyser.plot_smoothed(
    #         "H2",
    #         "log_return",
    #         "trend_log_return",
    #         smooth_window,
    #         "Price Log Return",
    #         "Trend Log Return",
    #         f"H2 {year}: {coin_name} Price Log Return vs Trend Log Return (rolling window={smooth_window})",
    #     )
    # analyser.plot_smoothed(
    #     "H1",
    #     "abs_log_return",
    #     "abs_trend_log_return",
    #     smooth_window,
    #     "Price Abs Log Return",
    #     f"Trend Abs Log Return({trend})",
    #     f"H1 {year}: {coin_name} Price Abs Log Return vs Trend Abs Log Return (rolling window={smooth_window})",
    # )
    # analyser.plot_smoothed(
    #     "H2",
    #     "abs_log_return",
    #     "abs_trend_log_return",
    #     smooth_window,
    #     "Price Abs Log Return",
    #     f"Trend Abs Log Return ({trend})",
    #     f"H2 {year}: {coin_name} Price Abs Log Return vs Trend Abs Log Return (rolling window={smooth_window})",
    # )
# Out:
# Granger causality results for H1 in 2021:
#
# === Testing Granger causality up to lag=3 in 2021 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3619  , p=0.5482  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=0.3680  , p=0.5441  , df=1
# likelihood ratio test: chi2=0.3677  , p=0.5443  , df=1
# parameter F test:         F=0.3619  , p=0.5482  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.9772  , p=0.1416  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=4.0679  , p=0.1308  , df=2
# likelihood ratio test: chi2=4.0224  , p=0.1338  , df=2
# parameter F test:         F=1.9772  , p=0.1416  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4000  , p=0.2446  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=4.3718  , p=0.2240  , df=3
# likelihood ratio test: chi2=4.3190  , p=0.2290  , df=3
# parameter F test:         F=1.4000  , p=0.2446  , df_denom=171, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2579  , p=0.6122  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=0.2623  , p=0.6085  , df=1
# likelihood ratio test: chi2=0.2621  , p=0.6087  , df=1
# parameter F test:         F=0.2579  , p=0.6122  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3972  , p=0.6728  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=0.8172  , p=0.6646  , df=2
# likelihood ratio test: chi2=0.8154  , p=0.6652  , df=2
# parameter F test:         F=0.3972  , p=0.6728  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4094  , p=0.7465  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=1.2783  , p=0.7343  , df=3
# likelihood ratio test: chi2=1.2738  , p=0.7354  , df=3
# parameter F test:         F=0.4094  , p=0.7465  , df_denom=171, df_num=3
#
# Granger causality results for H2 in 2021:
#
# === Testing Granger causality up to lag=3 in 2021 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0041  , p=0.9490  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=0.0042  , p=0.9485  , df=1
# likelihood ratio test: chi2=0.0042  , p=0.9485  , df=1
# parameter F test:         F=0.0041  , p=0.9490  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1163  , p=0.8903  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=0.2392  , p=0.8873  , df=2
# likelihood ratio test: chi2=0.2390  , p=0.8873  , df=2
# parameter F test:         F=0.1163  , p=0.8903  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1236  , p=0.9461  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=0.3856  , p=0.9432  , df=3
# likelihood ratio test: chi2=0.3852  , p=0.9433  , df=3
# parameter F test:         F=0.1236  , p=0.9461  , df_denom=174, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.0519  , p=0.0051  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=8.1861  , p=0.0042  , df=1
# likelihood ratio test: chi2=8.0083  , p=0.0047  , df=1
# parameter F test:         F=8.0519  , p=0.0051  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.7845  , p=0.0095  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=9.8393  , p=0.0073  , df=2
# likelihood ratio test: chi2=9.5825  , p=0.0083  , df=2
# parameter F test:         F=4.7845  , p=0.0095  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.8214  , p=0.0110  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=11.9255 , p=0.0076  , df=3
# likelihood ratio test: chi2=11.5491 , p=0.0091  , df=3
# parameter F test:         F=3.8214  , p=0.0110  , df_denom=174, df_num=3
#
# Granger causality results for H1 in 2022:
#
# === Testing Granger causality up to lag=3 in 2022 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3875  , p=0.5344  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=0.3940  , p=0.5302  , df=1
# likelihood ratio test: chi2=0.3936  , p=0.5304  , df=1
# parameter F test:         F=0.3875  , p=0.5344  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3279  , p=0.7209  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=0.6746  , p=0.7137  , df=2
# likelihood ratio test: chi2=0.6733  , p=0.7142  , df=2
# parameter F test:         F=0.3279  , p=0.7209  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2215  , p=0.8814  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=0.6918  , p=0.8751  , df=3
# likelihood ratio test: chi2=0.6904  , p=0.8755  , df=3
# parameter F test:         F=0.2215  , p=0.8814  , df_denom=171, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.8599  , p=0.0288  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=4.9423  , p=0.0262  , df=1
# likelihood ratio test: chi2=4.8756  , p=0.0272  , df=1
# parameter F test:         F=4.8599  , p=0.0288  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.2809  , p=0.1052  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=4.6930  , p=0.0957  , df=2
# likelihood ratio test: chi2=4.6325  , p=0.0986  , df=2
# parameter F test:         F=2.2809  , p=0.1052  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.7192  , p=0.0462  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=8.4916  , p=0.0369  , df=3
# likelihood ratio test: chi2=8.2953  , p=0.0403  , df=3
# parameter F test:         F=2.7192  , p=0.0462  , df_denom=171, df_num=3
#
# Granger causality results for H2 in 2022:
#
# === Testing Granger causality up to lag=3 in 2022 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.0621  , p=0.1527  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=2.0965  , p=0.1476  , df=1
# likelihood ratio test: chi2=2.0846  , p=0.1488  , df=1
# parameter F test:         F=2.0621  , p=0.1527  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1013  , p=0.3347  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=2.2648  , p=0.3223  , df=2
# likelihood ratio test: chi2=2.2508  , p=0.3245  , df=2
# parameter F test:         F=1.1013  , p=0.3347  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8141  , p=0.4877  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=2.5406  , p=0.4680  , df=3
# likelihood ratio test: chi2=2.5229  , p=0.4712  , df=3
# parameter F test:         F=0.8141  , p=0.4877  , df_denom=174, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4458  , p=0.5052  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=0.4533  , p=0.5008  , df=1
# likelihood ratio test: chi2=0.4527  , p=0.5011  , df=1
# parameter F test:         F=0.4458  , p=0.5052  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.7700  , p=0.0015  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=13.9226 , p=0.0009  , df=2
# likelihood ratio test: chi2=13.4157 , p=0.0012  , df=2
# parameter F test:         F=6.7700  , p=0.0015  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.2050  , p=0.0067  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=13.1224 , p=0.0044  , df=3
# likelihood ratio test: chi2=12.6685 , p=0.0054  , df=3
# parameter F test:         F=4.2050  , p=0.0067  , df_denom=174, df_num=3
#
# Granger causality results for H1 in 2023:
#
# === Testing Granger causality up to lag=3 in 2023 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.5843  , p=0.1097  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=2.6281  , p=0.1050  , df=1
# likelihood ratio test: chi2=2.6091  , p=0.1063  , df=1
# parameter F test:         F=2.5843  , p=0.1097  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5023  , p=0.2255  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=3.0910  , p=0.2132  , df=2
# likelihood ratio test: chi2=3.0646  , p=0.2160  , df=2
# parameter F test:         F=1.5023  , p=0.2255  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6290  , p=0.5972  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=1.9642  , p=0.5799  , df=3
# likelihood ratio test: chi2=1.9534  , p=0.5821  , df=3
# parameter F test:         F=0.6290  , p=0.5972  , df_denom=171, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0071  , p=0.9330  , df_denom=177, df_num=1
# ssr based chi2 test:   chi2=0.0072  , p=0.9323  , df=1
# likelihood ratio test: chi2=0.0072  , p=0.9323  , df=1
# parameter F test:         F=0.0071  , p=0.9330  , df_denom=177, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=12.2792 , p=0.0000  , df_denom=174, df_num=2
# ssr based chi2 test:   chi2=25.2640 , p=0.0000  , df=2
# likelihood ratio test: chi2=23.6330 , p=0.0000  , df=2
# parameter F test:         F=12.2792 , p=0.0000  , df_denom=174, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=8.8686  , p=0.0000  , df_denom=171, df_num=3
# ssr based chi2 test:   chi2=27.6948 , p=0.0000  , df=3
# likelihood ratio test: chi2=25.7406 , p=0.0000  , df=3
# parameter F test:         F=8.8686  , p=0.0000  , df_denom=171, df_num=3
#
# Granger causality results for H2 in 2023:
#
# === Testing Granger causality up to lag=3 in 2023 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.2292  , p=0.2690  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=1.2497  , p=0.2636  , df=1
# likelihood ratio test: chi2=1.2454  , p=0.2644  , df=1
# parameter F test:         F=1.2292  , p=0.2690  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.6145  , p=0.0760  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=5.3766  , p=0.0680  , df=2
# likelihood ratio test: chi2=5.2987  , p=0.0707  , df=2
# parameter F test:         F=2.6145  , p=0.0760  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2735  , p=0.0818  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=7.0950  , p=0.0689  , df=3
# likelihood ratio test: chi2=6.9595  , p=0.0732  , df=3
# parameter F test:         F=2.2735  , p=0.0818  , df_denom=174, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=14.6368 , p=0.0002  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=14.8807 , p=0.0001  , df=1
# likelihood ratio test: chi2=14.3066 , p=0.0002  , df=1
# parameter F test:         F=14.6368 , p=0.0002  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=13.6803 , p=0.0000  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=28.1335 , p=0.0000  , df=2
# likelihood ratio test: chi2=26.1600 , p=0.0000  , df=2
# parameter F test:         F=13.6803 , p=0.0000  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=8.5112  , p=0.0000  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=26.5607 , p=0.0000  , df=3
# likelihood ratio test: chi2=24.7837 , p=0.0000  , df=3
# parameter F test:         F=8.5112  , p=0.0000  , df_denom=174, df_num=3
#
# Granger causality results for H1 in 2024:
#
# === Testing Granger causality up to lag=3 in 2024 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1797  , p=0.6721  , df_denom=178, df_num=1
# ssr based chi2 test:   chi2=0.1828  , p=0.6690  , df=1
# likelihood ratio test: chi2=0.1827  , p=0.6691  , df=1
# parameter F test:         F=0.1797  , p=0.6721  , df_denom=178, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4988  , p=0.6081  , df_denom=175, df_num=2
# ssr based chi2 test:   chi2=1.0262  , p=0.5986  , df=2
# likelihood ratio test: chi2=1.0232  , p=0.5995  , df=2
# parameter F test:         F=0.4988  , p=0.6081  , df_denom=175, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3033  , p=0.8229  , df_denom=172, df_num=3
# ssr based chi2 test:   chi2=0.9471  , p=0.8141  , df=3
# likelihood ratio test: chi2=0.9446  , p=0.8147  , df=3
# parameter F test:         F=0.3033  , p=0.8229  , df_denom=172, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0584  , p=0.8094  , df_denom=178, df_num=1
# ssr based chi2 test:   chi2=0.0593  , p=0.8076  , df=1
# likelihood ratio test: chi2=0.0593  , p=0.8076  , df=1
# parameter F test:         F=0.0584  , p=0.8094  , df_denom=178, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3031  , p=0.1030  , df_denom=175, df_num=2
# ssr based chi2 test:   chi2=4.7379  , p=0.0936  , df=2
# likelihood ratio test: chi2=4.6766  , p=0.0965  , df=2
# parameter F test:         F=2.3031  , p=0.1030  , df_denom=175, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2319  , p=0.2997  , df_denom=172, df_num=3
# ssr based chi2 test:   chi2=3.8462  , p=0.2786  , df=3
# likelihood ratio test: chi2=3.8055  , p=0.2832  , df=3
# parameter F test:         F=1.2319  , p=0.2997  , df_denom=172, df_num=3
#
# Granger causality results for H2 in 2024:
#
# === Testing Granger causality up to lag=3 in 2024 ===
#
# >> Does TREND Granger-cause PRICE?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.4500  , p=0.0363  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=4.5242  , p=0.0334  , df=1
# likelihood ratio test: chi2=4.4692  , p=0.0345  , df=1
# parameter F test:         F=4.4500  , p=0.0363  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.0122  , p=0.0517  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=6.1946  , p=0.0452  , df=2
# likelihood ratio test: chi2=6.0915  , p=0.0476  , df=2
# parameter F test:         F=3.0122  , p=0.0517  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.6820  , p=0.0484  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=8.3696  , p=0.0390  , df=3
# likelihood ratio test: chi2=8.1819  , p=0.0424  , df=3
# parameter F test:         F=2.6820  , p=0.0484  , df_denom=174, df_num=3
#
# >> Does PRICE Granger-cause TREND?
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=16.8733 , p=0.0001  , df_denom=180, df_num=1
# ssr based chi2 test:   chi2=17.1545 , p=0.0000  , df=1
# likelihood ratio test: chi2=16.3975 , p=0.0001  , df=1
# parameter F test:         F=16.8733 , p=0.0001  , df_denom=180, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=9.0107  , p=0.0002  , df_denom=177, df_num=2
# ssr based chi2 test:   chi2=18.5305 , p=0.0001  , df=2
# likelihood ratio test: chi2=17.6466 , p=0.0001  , df=2
# parameter F test:         F=9.0107  , p=0.0002  , df_denom=177, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.2042  , p=0.0018  , df_denom=174, df_num=3
# ssr based chi2 test:   chi2=16.2406 , p=0.0010  , df=3
# likelihood ratio test: chi2=15.5529 , p=0.0014  , df=3
# parameter F test:         F=5.2042  , p=0.0018  , df_denom=174, df_num=3
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/dsf-air-17/Dev/nodiens_index/venv/lib/python3.13/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
